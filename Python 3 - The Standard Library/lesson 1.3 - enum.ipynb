# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Перечисление - это набор именованных констант, имеющие два атрибута имя и значение.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Пустое перечисление создать не получится:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Чаще всего используют неизменяемые типы, так как, например, изменяемый список формально можно модифицировать после объявления класса.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from enum import Enum

class StyleWindow(Enum):
    CAPTION = 1
    DIALOG = 2
    BORDER = 4

class WindowStyle(Enum):
    CAPTION = 1
    DIALOG = 2
    BORDER = 4


p1 = StyleWindow.DIALOG
p2 = WindowStyle.DIALOG

# print(p1 <= p2)
print(p1 == 2)
# Out:
# False

# %%
a = 4.3, 2.1
# a[0] = int(a[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 a = 4.3, 2.1
# ----> 2 a[0] = int(a[0])
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ![image.png](attachment:image.png)
